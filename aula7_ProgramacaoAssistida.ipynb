# %% [markdown]
# <a href="https://colab.research.google.com/github/jotinha0807/engenharia_de_prompt_aplicacoes_ai/blob/main/aula7_ProgramacaoAssistida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula: Programação Assistida
# João Victor Sousa dos Anjos miranda( turma sextou)

# %%
# Define a list of numbers
numbers = [20,30,50,60,750,633]

# Initialize a variable to store the total sum
total_sum = 0

# Iterate through each number in the list
for num in numbers:
    # Add the current number to the total_sum
    total_sum += num

# Print the calculated sum
print(f"The sum of the numbers is: {total_sum}")
# Print the original list of numbers
print(f"The original list is: {numbers}")
# Out:
# The sum of the numbers is: 1543
# The original list is: [20, 30, 50, 60, 750, 633]
